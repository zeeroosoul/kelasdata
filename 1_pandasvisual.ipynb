# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/ahmad/Documents/belajarkoding/kelasdata/data/sdindo2023.csv")

# %%
df = data["Provinsi"]
data.set_index("Provinsi", drop = True)
# Out:
#                         Sekolah    Siswa  Mengulang  Putus Sekolah  \
# Provinsi
# Prov. D.K.I. Jakarta       1305   540938        915            695
# Prov. Jawa Barat          17104  3891806       4563           5080
# Prov. Jawa Tengah         17298  2280299       6696           2166
# Prov. D.I. Yogyakarta      1422   186752        308             43
# Prov. Jawa Timur          16902  2130520       4172           2579
# ...                         ...      ...        ...            ...
# Luar Negeri                  41     5871          9              8
# Prov. Papua Tengah          262    73033       1958            636
# Prov. Papua Selatan         234    38962       2169            356
# Prov. Papua Pegunungan      152    30722        405            220
# Prov. Papua Barat Daya      245    24943        422            112
#
#                         Kepala Sekolah & Guru  Tenaga Kependidikan  Rombel  \
# Provinsi
# Prov. D.K.I. Jakarta                    22899                 2443   18247
# Prov. Jawa Barat                       162220                11771  144349
# Prov. Jawa Tengah                      137177                 9996  113671
# Prov. D.I. Yogyakarta                   13190                 1900    9815
# Prov. Jawa Timur                       143558                10282  115931
# ...                                       ...                  ...     ...
# Luar Negeri                               148                    0     288
# Prov. Papua Tengah                       1990                   60    2499
# Prov. Papua Selatan                      1449                   66    1736
# Prov. Papua Pegunungan                    905                   33    1105
# Prov. Papua Barat Daya                   1460                   93    1607
#
#                         Ruang Kelas  Status
# Provinsi
# Prov. D.K.I. Jakarta          17197  Negeri
# Prov. Jawa Barat             127023  Negeri
# Prov. Jawa Tengah            118675  Negeri
# Prov. D.I. Yogyakarta         10328  Negeri
# Prov. Jawa Timur             120304  Negeri
# ...                             ...     ...
# Luar Negeri                     233  Swasta
# Prov. Papua Tengah             2192  Swasta
# Prov. Papua Selatan            1679  Swasta
# Prov. Papua Pegunungan         1043  Swasta
# Prov. Papua Barat Daya         1646  Swasta
#
# [78 rows x 9 columns]
